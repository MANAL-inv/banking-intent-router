# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
import importlib
import src.track_b
importlib.reload(src.track_b)

results_b = src.track_b.run()
results_b
# Out:
# embedding dim: 384  train shape: (8103, 384)
#
# emb_logreg_C1        val_macro_f1=0.9086 acc=0.9049 (0.9s)
# emb_logreg_C3        val_macro_f1=0.9143 acc=0.9112 (1.2s)
# emb_logreg_C10       val_macro_f1=0.9166 acc=0.9140 (1.6s)
# emb_logreg_C30       val_macro_f1=0.9177 acc=0.9147 (2.2s)
# emb_logreg_C100      val_macro_f1=0.9168 acc=0.9140 (2.3s)
# emb_logreg_C300      val_macro_f1=0.9181 acc=0.9140 (2.4s)
# emb_knn_k1           val_macro_f1=0.9066 acc=0.9035 (0.0s)
# emb_knn_k5           val_macro_f1=0.9112 acc=0.9063 (0.0s)
# emb_knn_k15          val_macro_f1=0.9048 acc=0.9014 (0.0s)
# emb_centroid         val_macro_f1=0.8529 acc=0.8483 (0.0s)
#
# selection: argmax=emb_logreg_C300 (0.9181), SE=0.0074, 6 within 1 SE -> selected emb_logreg_C3
# TEST in-scope: macro_f1=0.9212 acc=0.9214
#              model  fit_seconds  accuracy  macro_f1
# 5  emb_logreg_C300         2.44  0.913986  0.918072
# 3   emb_logreg_C30         2.18  0.914685  0.917692
# ...
